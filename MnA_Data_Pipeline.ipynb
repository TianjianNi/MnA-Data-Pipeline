# %% [markdown]
# #MnA Data Pipeline

# %% [markdown]
# **Demo of data pipeline to download MnA data from Refinitiv through Eikon Data API**
#
# Author: Tianjian Ni

# %% [markdown]
# **Following the link to get access:** https://guides.nyu.edu/c.php?g=1331053&p=9802251
# 1.   Request an LSEG Workspace account (if you do not have an existing one)
# 2.   Request access to SDC Platinum via LSEG Workspace (Google Form)
#
#
# **Download LSEG Workspace and login:** https://www.lseg.com/en/data-analytics/products/workspace/download-workspace

# %% [markdown]
# Run the following command to install or upgrade the Eikon package

# %%
pip install eikon # pip install --upgrade eikon
# Out:
# Requirement already satisfied: eikon in /Users/tianjianni/opt/anaconda3/lib/python3.9/site-packages (1.1.18)
# Requirement already satisfied: idna==2.* in /Users/tianjianni/opt/anaconda3/lib/python3.9/site-packages (from eikon) (2.10)
# Requirement already satisfied: websocket-client!=1.0.0,>=0.54.0 in /Users/tianjianni/opt/anaconda3/lib/python3.9/site-packages (from eikon) (0.58.0)
# Requirement already satisfied: chardet==3.* in /Users/tianjianni/opt/anaconda3/lib/python3.9/site-packages (from eikon) (3.0.4)
# Requirement already satisfied: rfc3986==1.* in /Users/tianjianni/opt/anaconda3/lib/python3.9/site-packages (from eikon) (1.5.0)
# Requirement already satisfied: appdirs>=1.4.3 in /Users/tianjianni/opt/anaconda3/lib/python3.9/site-packages (from eikon) (1.4.4)
# Requirement already satisfied: numpy>=1.11.0 in /Users/tianjianni/opt/anaconda3/lib/python3.9/site-packages (from eikon) (1.21.5)
# Requirement already satisfied: python-dateutil in /Users/tianjianni/opt/anaconda3/lib/python3.9/site-packages (from eikon) (2.8.2)
# Requirement already satisfied: requests==2.* in /Users/tianjianni/opt/anaconda3/lib/python3.9/site-packages (from eikon) (2.28.1)
# Requirement already satisfied: datetime in /Users/tianjianni/opt/anaconda3/lib/python3.9/site-packages (from eikon) (5.4)
# Requirement already satisfied: deprecation in /Users/tianjianni/opt/anaconda3/lib/python3.9/site-packages (from eikon) (2.1.0)
# Requirement already satisfied: certifi in /Users/tianjianni/opt/anaconda3/lib/python3.9/site-packages (from eikon) (2022.9.24)
# Requirement already satisfied: h2==4.* in /Users/tianjianni/opt/anaconda3/lib/python3.9/site-packages (from eikon) (4.1.0)
# Requirement already satisfied: httpx>=0.18.0 in /Users/tianjianni/opt/anaconda3/lib/python3.9/site-packages (from eikon) (0.26.0)
# Requirement already satisfied: pandas>=1.0.0 in /Users/tianjianni/opt/anaconda3/lib/python3.9/site-packages (from eikon) (1.4.4)
# Requirement already satisfied: nest-asyncio>=1.5.1 in /Users/tianjianni/opt/anaconda3/lib/python3.9/site-packages (from eikon) (1.5.5)
# Requirement already satisfied: hyperframe<7,>=6.0 in /Users/tianjianni/opt/anaconda3/lib/python3.9/site-packages (from h2==4.*->eikon) (6.0.1)
# Requirement already satisfied: hpack<5,>=4.0 in /Users/tianjianni/opt/anaconda3/lib/python3.9/site-packages (from h2==4.*->eikon) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/tianjianni/opt/anaconda3/lib/python3.9/site-packages (from requests==2.*->eikon) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/tianjianni/opt/anaconda3/lib/python3.9/site-packages (from requests==2.*->eikon) (2.0.4)
# Requirement already satisfied: anyio in /Users/tianjianni/opt/anaconda3/lib/python3.9/site-packages (from httpx>=0.18.0->eikon) (3.5.0)
# Requirement already satisfied: sniffio in /Users/tianjianni/opt/anaconda3/lib/python3.9/site-packages (from httpx>=0.18.0->eikon) (1.2.0)
# Requirement already satisfied: httpcore==1.* in /Users/tianjianni/opt/anaconda3/lib/python3.9/site-packages (from httpx>=0.18.0->eikon) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/tianjianni/opt/anaconda3/lib/python3.9/site-packages (from httpcore==1.*->httpx>=0.18.0->eikon) (0.14.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/tianjianni/opt/anaconda3/lib/python3.9/site-packages (from pandas>=1.0.0->eikon) (2022.1)
# Requirement already satisfied: six>=1.5 in /Users/tianjianni/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil->eikon) (1.16.0)
# Requirement already satisfied: zope.interface in /Users/tianjianni/opt/anaconda3/lib/python3.9/site-packages (from datetime->eikon) (5.4.0)
# Requirement already satisfied: packaging in /Users/tianjianni/opt/anaconda3/lib/python3.9/site-packages (from deprecation->eikon) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/tianjianni/opt/anaconda3/lib/python3.9/site-packages (from packaging->deprecation->eikon) (3.0.9)
# Requirement already satisfied: setuptools in /Users/tianjianni/opt/anaconda3/lib/python3.9/site-packages (from zope.interface->datetime->eikon) (67.8.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Import necessary libraries for the Demo

# %%
import datetime
import pandas as pd
import eikon as ek

# %% [markdown]
# **Use local environment to run the Demo instead of Colab. Make sure Refinitiv Workspace is running in the background**
#
# App Key should be generated following the Demo in the link: https://developers.lseg.com/en/api-catalog/eikon/eikon-data-api/quick-start

# %%
# Parameters Selection

# The API Key
API_KEY = 'YOUR API KEY'
ek.set_app_key(API_KEY)

# Folder directory to save retrieved datasets
DATA_FILE_PATH = 'CSV FILE PATH'

# Start year and month for the data retrieval
YEAR_START = 2022
MONTH_START = 1

# End year and month for the data retrieval
YEAR_END = 2022
MONTH_END = 2

# %% [markdown]
# Test run

# %%
deal, err = ek.get_data("SCREEN(U(IN(DEALS)), IN(TR.MnAStatus,""U"",""C""), BETWEEN(TR.MnARankDate,20230101,20230107), CURN=USD)",
                            ["TR.MnASDCDealNumber","TR.MnAAnnDate","TR.MnATarget","TR.MnATargetPermId",
                             "TR.MnATargetMacroInd","TR.MnATargetMidInd","TR.MnATargetNation",
                             "TR.MnAAcquiror","TR.MnAAcquirorPermId","TR.MnAAcquirorMacroInd",
                             "TR.MnAAcquirorMidInd","TR.MnAAcquirorNation",
                             "TR.MnATargetFinAdvisor(Concat='|')",
                             "TR.MnAAcquirorFinAdvisor(Concat='|')", "TR.MnAStatus"],{"Curn":"USD"})
deal
# Out:
#        Instrument  SDC Deal No Date Announced  \
# 0     34392764239   2460476040     2023-01-06
# 1    154087627841   3942084040     2023-01-06
# 2    154087651176   3953580040     2022-07-25
# 3    154087684460   3966595040     2023-01-03
# 4    154087694370   3970799040     2023-01-01
# ..            ...          ...            ...
# 907  154088367456   4186546040     2023-01-03
# 908  154088378450   4191378040     2023-01-01
# 909  154088378458   4191383040     2023-01-01
# 910  154088383192   4193455040     2023-01-01
# 911  154088389187   4195189040     2023-01-07
#
#                                       Target Full Name  Target PermID  \
# 0             Cia Mexicana de Aviacion SA de CV-assets           <NA>
# 1                                   Maisons Phenix SAS     5083328212
# 2            Zhejiang Xiantong Rubber & Plastic Co Ltd     5000541243
# 3                                   Soprano Design Ltd     5044035090
# 4    EBL (Genossenschaft Elektra Baselland)-Telecom...           <NA>
# ..                                                 ...            ...
# 907                                           GPDQ Ltd     5074208192
# 908                         User Interface Design GmbH     5037647591
# 909                                Gardien Europe GmbH           <NA>
# 910                                           Beit Inc     5086135261
# 911  Guangdong Dongfang Precision Science & Technol...     5035418673
#
#     Target Macro Industry                  Target Mid Industry  \
# 0             Industrials      Transportation & Infrastructure
# 1             Industrials  Building/Construction & Engineering
# 2             Industrials             Automobiles & Components
# 3         High Technology                             Software
# 4      Telecommunications          Telecommunications Services
# ..                    ...                                  ...
# 907       High Technology                             Software
# 908       High Technology                             Software
# 909           Industrials                            Machinery
# 910       High Technology                             Software
# 911           Industrials                            Machinery
#
#         Target Nation                                 Acquiror Full Name  \
# 0              Mexico                  Secretaria de la Defensa Nacional
# 1              France                      Sologne Et Loire Habitat SASU
# 2    China (Mainland)      Taizhou Wucheng Industrial Development Co Ltd
# 3           Australia                           Potentia Capital Pty Ltd
# 4         Switzerland                                   Sunrise UPC GmbH
# ..                ...                                                ...
# 907    United Kingdom                                     IW Capital Ltd
# 908           Germany                                        Bayoonet AG
# 909           Germany                        Gardien Services Canada Inc
# 910            Poland                                    Tensor Ventures
# 911  China (Mainland)  Guangdong Dongfang Precision Science & Technol...
#
#      Acquiror PermID  Acquiror Macro Industry  \
# 0         5038985397  Government and Agencies
# 1         4298160662              Industrials
# 2         5083467230              Industrials
# 3         5054881767               Financials
# 4         5044507453       Telecommunications
# ..               ...                      ...
# 907       5044029309               Financials
# 908       5045201023          High Technology
# 909       5045188068              Industrials
# 910       5082240214               Financials
# 911       5035418673              Industrials
#
#                    Acquiror Mid Industry   Acquiror Nation  \
# 0                    National Government            Mexico
# 1    Building/Construction & Engineering            France
# 2               Automobiles & Components  China (Mainland)
# 3      Alternative Financial Investments         Australia
# 4                               Wireless       Switzerland
# ..                                   ...               ...
# 907                     Other Financials    United Kingdom
# 908                             Software           Germany
# 909                            Machinery            Canada
# 910    Alternative Financial Investments    Czech Republic
# 911                            Machinery  China (Mainland)
#
#     Target Financial Advisors Name Acquiror Financial Advisors Name  \
# 0                             <NA>                             <NA>
# 1                             <NA>                             <NA>
# 2                             <NA>          China Construction Bank
# 3                  Macquarie Group                             <NA>
# 4                             <NA>                             <NA>
# ..                             ...                              ...
# 907                           <NA>                             <NA>
# 908                           <NA>                             <NA>
# 909                           <NA>                             <NA>
# 910                           <NA>                             <NA>
# 911                           <NA>                             <NA>
#
#     Deal Status
# 0     Completed
# 1     Completed
# 2     Completed
# 3     Completed
# 4     Completed
# ..          ...
# 907   Completed
# 908   Completed
# 909   Completed
# 910   Completed
# 911   Completed
#
# [912 rows x 16 columns]

# %% [markdown]
# **Additional fields/columns can be selected** https://developers.lseg.com/en/article-catalog/article/find-your-right-companies-with-screener-eikon-data-apis-python

# %%
# Select columns to include in the dataset
fields = []

# Deal Info
fields.append("TR.MNASDCDealNumber")
fields.append("TR.MnAAnnDate")
fields.append("TR.MnARankDate")
fields.append("TR.MnARankValueIncNetDebt(Curn=USD,Scale=6)")

# Acquiror Info
fields.append("TR.MnATarget")
fields.append("TR.MnATargetMacroInd")
fields.append("TR.MnATargetMidInd")
fields.append("TR.MnATargetNation")

# Acquiror Info
fields.append("TR.MnAAcquiror")
fields.append("TR.MnAAcquirorMacroInd")
fields.append("TR.MnAAcquirorMidInd")
fields.append("TR.MnAAcquirorNation")

# Financial Info
fields.append("TR.MnAEnterpriseValueAtAnnouncementDate(Curn=USD,Scale=6)")
# ... Add more, can look up in Refinitiv Workspace
# fields.append("")
# fields.append("")
fields.append("TR.MnAEnterpriseValueToSales")
fields.append("TR.MnAEnterpriseValueToEBIT")
fields.append("TR.MnAEnterpriseValueToEBIDTA")
fields.append("TR.MnAEnterpriseValueToNetIncome")
fields.append("TR.MnATargetStockOnAnn(Curn=USD)")
fields.append("TR.MnAStatus")

# %% [markdown]
# The datasets are downloaded by month into CSVs since each API call can only download 15,000 rows

# %%
def download_data_between_dates(start_date, end_date):

    current_date = start_date
    while current_date <= end_date:

        next_month = current_date.replace(day=28) + datetime.timedelta(days=4)
        end_of_month = next_month - datetime.timedelta(days=next_month.day)
        
        MnA_filter = f"U(IN(DEALS))"
        completed_deals_filter = f"IN(TR.MnAStatus,""U"",""C"")"
        date_filter = f'BETWEEN(TR.MnARankDate,{current_date.strftime("%Y%m%d")},{end_of_month.strftime("%Y%m%d")})/*dt:Date*/'
        currency_filter = f"CURN=USD"
        
        screen = f'SCREEN( {MnA_filter}, {completed_deals_filter}, {date_filter}, {currency_filter})'
        
        df, err = ek.get_data(screen, fields) # ek.get_data() returns a tuple, we only used the dataframe part and ignore the error part
        print(f'Screen for year/month {current_date.strftime("%Y/%m")}: {screen}')

        file_path = f'{DATA_FILE_PATH}{current_date.strftime("%Y%m%d")}_{end_of_month.strftime("%Y%m%d")}.csv'
        print(f'File saved in {file_path}')
        df.to_csv(file_path, index = False)

        current_date = end_of_month + datetime.timedelta(days=1)

# %%
print("Start to download the datasets ...........")
download_data_between_dates(datetime.date(YEAR_START, MONTH_START, 1), datetime.date(YEAR_END, MONTH_END, 1))
print("Download finished")
# Out:
# Start to download the datasets ...........
# Screen for year/month 2022/01: SCREEN( U(IN(DEALS)), IN(TR.MnAStatus,U,C), BETWEEN(TR.MnARankDate,20220101,20220131)/*dt:Date*/, CURN=USD)
# File saved in /Users/tianjianni/Desktop/MnA20220101_20220131.csv
# Screen for year/month 2022/02: SCREEN( U(IN(DEALS)), IN(TR.MnAStatus,U,C), BETWEEN(TR.MnARankDate,20220201,20220228)/*dt:Date*/, CURN=USD)
# File saved in /Users/tianjianni/Desktop/MnA20220201_20220228.csv
# Download finished
